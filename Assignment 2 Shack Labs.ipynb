# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\Siddharth Sagar\OneDrive\Desktop\Python\flipkart_sample.csv')
print(data)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
data.head(20)
# Out:
#                              uniq_id            crawl_timestamp  \
# 0   c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1   7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2   f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3   0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4   bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# 5   c2a17313954882c1dba461863e98adf2  2016-03-25 22:59:23 +0000
# 6   ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# 7   8542703ca9e6ebdf6d742638dfb1f2ca  2016-03-25 22:59:23 +0000
# 8   29c8d290caa451f97b1c32df64477a2c  2016-03-25 22:59:23 +0000
# 9   4044c0ac52c1ee4b28777417651faf42  2016-03-25 22:59:23 +0000
# 10  e54bc0a7c3429da2ebef0b30331fe3d2  2016-03-25 22:59:23 +0000
# 11  c73e78fb440ff8972e0762daed4fc109  2016-03-25 22:59:23 +0000
# 12  c29af37837afcaf44b779eca7c19295f  2016-03-25 22:59:23 +0000
# 13  9aacdecceb404c74abddc513fd2756a8  2016-03-25 22:59:23 +0000
# ...

# %%
df1 = pd.DataFrame(data)

# %%
print (df1)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
data_1 = pd.read_csv(r'C:\Users\Siddharth Sagar\OneDrive\Desktop\Python\Amazon_sample.csv',  encoding= 'unicode_escape')
print(data_1)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
data_1.head(20)
# Out:
#                              uniq_id            crawl_timestamp  \
# 0   c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1   7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2   f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3   0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4   bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# 5   c2a17313954882c1dba461863e98adf2  2016-03-25 22:59:23 +0000
# 6   ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# 7   8542703ca9e6ebdf6d742638dfb1f2ca  2016-03-25 22:59:23 +0000
# 8   29c8d290caa451f97b1c32df64477a2c  2016-03-25 22:59:23 +0000
# 9   4044c0ac52c1ee4b28777417651faf42  2016-03-25 22:59:23 +0000
# 10  e54bc0a7c3429da2ebef0b30331fe3d2  2016-03-25 22:59:23 +0000
# 11  c73e78fb440ff8972e0762daed4fc109  2016-03-25 22:59:23 +0000
# 12  c29af37837afcaf44b779eca7c19295f  2016-03-25 22:59:23 +0000
# 13  9aacdecceb404c74abddc513fd2756a8  2016-03-25 22:59:23 +0000
# ...

# %%
df2 = pd.DataFrame(data_1)

# %%
print (df2)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
data.shape
# Out:
# (20000, 15)

# %%
data_1.shape
# Out:
# (20000, 15)

# %%
! pip install datacompy

# %%
import datacompy

# %%
compare = datacompy.Compare(data,data_1,on_index = True, abs_tol=0.0001, rel_tol=0,)
print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns   Rows
# 0       df1       15  20000
# 1       df2       15  20000
#
# Column Summary
# --------------
#
# Number of columns in common: 15
# Number of columns in df1 but not in df2: 0
# Number of columns in df2 but not in df1: 0
#
# Row Summary
# -----------
#
# Matched on: index
# Any duplicates on match values: No
# Absolute Tolerance: 0.0001
# Relative Tolerance: 0
# Number of rows in common: 20,000
# Number of rows in df1 but not in df2: 0
# Number of rows in df2 but not in df1: 0
#
# Number of rows with some compared columns unequal: 20,000
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 7
# Number of columns compared with all values equal: 8
# Total number of values which compare unequal: 44,642
#
# Columns with Unequal Values or Types
# ...

# %%
df3 = pd.DataFrame('compare')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df3 = pd.DataFrame('compare')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
compare.intersect_columns()
# Out:
# OrderedSet(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name', 'product_category_tree', 'pid', 'retail_price', 'discounted_price', 'image', 'is_fk_advantage_product', 'description', 'product_rating', 'overall_rating', 'brand', 'product_specifications'])

# %%
df1['retail_price'] = df2['retail_price']
df1['prices_match'] = np.where(df1['retail_price'] == df2['retail_price'], 'True', 'False')
df1['price_diff'] = np.where(df1['retail_price'] == df2['retail_price'], 0, df1['retail_price'] - df2['retail_price'])

# %%
print(df1)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...
