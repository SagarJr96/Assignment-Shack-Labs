# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_excel(r'C:\Users\Siddharth Sagar\Downloads\Assignment.xlsx')
print(data)
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0         2012.916667       32.0                                  84.87882
# 1         2012.916667       19.5                                 306.59470
# 2         2013.583333       13.3                                 561.98450
# 3         2013.500000       13.3                                 561.98450
# 4         2012.833333        5.0                                 390.56840
# ..                ...        ...                                       ...
# 409       2013.000000       13.7                                4082.01500
# 410       2012.666667        5.6                                  90.45606
# 411       2013.250000       18.8                                 390.96960
# 412       2013.000000        8.1                                 104.81010
# 413       2013.500000        6.5                                  90.45606
#
# ...

# %%
data.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %%
data.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
data.shape
# Out:
# (414, 9)

# %%
data.isnull().sum()
# Out:
# Transaction date                            0
# House Age                                   0
# Distance from nearest Metro station (km)    0
# Number of convenience stores                0
# latitude                                    0
# longitude                                   0
# Number of bedrooms                          0
# House size (sqft)                           0
# House price of unit area                    0
# dtype: int64

# %%
data['Number of bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.latitude.values, y=data.longitude.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# C:\Users\Siddharth Sagar\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data['House price of unit area'],data['House size (sqft)'])
plt.title('Price vs Sqft')
# Out:
# Text(0.5, 1.0, 'Price vs Sqft')

# %%
plt.scatter(data['House price of unit area'],data['Number of bedrooms'])
plt.title('Price vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'Price vs Bedrooms')

# %%
plt.scatter(data['House price of unit area'],data['latitude'])
plt.title('Price vs Latitude')
# Out:
# Text(0.5, 1.0, 'Price vs Latitude')

# %%
plt.scatter(data['House price of unit area'],data['longitude'])
plt.title('Price vs Longitude')
# Out:
# Text(0.5, 1.0, 'Price vs Longitude')

# %%
plt.scatter(data['House price of unit area'],data['Number of convenience stores'])
plt.title('Price vs Stores')
# Out:
# Text(0.5, 1.0, 'Price vs Stores')

# %%
plt.scatter(data['House price of unit area'],data['Distance from nearest Metro station (km)'])
plt.title('Price vs Distance')
# Out:
# Text(0.5, 1.0, 'Price vs Distance')

# %%
plt.scatter(data['House price of unit area'],data['House Age'])
plt.title('Price vs House Age')
# Out:
# Text(0.5, 1.0, 'Price vs House Age')

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
labels=['House price of unit area']
conv_dates=[1 if value == 2013 else 0 for values in data['Transaction date] ]
data['Transaction date']=  conv_dates
train1= data.drop(['House Age', 'House price of unit area'],axis=1)
# Out:
#   Input In [16]
#     conv_dates=[1 if value == 2013 else 0 for values in data['Transaction date] ]
#                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.corr(),
            cmap = 'BrBG',
            fmt = '.2f',
            linewidths = 2,
            annot = True)
# Out:
# <AxesSubplot:>

# %%
unique_values = []
for col in object_cols:
    unique_values.append(data[col].unique().size)
plt.figure(figsize=(10,6))
plt.title('No. Unique values of Categorical Features')
plt.xticks(rotation=90)
sns.barplot(x=object_cols,y=unique_values)
pd.Series(dtype='float64')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 unique_values = []
# ----> 2 for col in object_cols:
#       3     unique_values.append(data[col].unique().size)
#       4 plt.figure(figsize=(10,6))
#
# NameError: name 'object_cols' is not defined

# %%
from sklearn.preprocessing import OneHotEncoder
 
s = (data.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ',
      len(object_cols))
# Out:
# Categorical variables:
# []
# No. of. categorical features:  0

# %%
OH_encoder = OneHotEncoder(sparse=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(data[object_cols]))
OH_cols.index = data.index
OH_cols.columns = OH_encoder.get_feature_names()
df_final = data.drop(object_cols, axis=1)
df_final = pd.concat([df_final, OH_cols], axis=1)
# Out:
# C:\Users\Siddharth Sagar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
 
X = df_final.drop(['House price of unit area'], axis=1)
Y = df_final['House price of unit area']
 
# Split the training set into
# training and validation set
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error
 
model_SVR = svm.SVR()
model_SVR.fit(X_train,Y_train)
Y_pred = model_SVR.predict(X_valid)
 
print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.19952337323280223

# %%
from sklearn.ensemble import RandomForestRegressor
 
model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, Y_train)
Y_pred = model_RFR.predict(X_valid)
 
mean_absolute_percentage_error(Y_valid, Y_pred)
# Out:
# 0.13361291490864624

# %%
from sklearn.linear_model import LinearRegression
 
model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred = model_LR.predict(X_valid)
 
print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.17012009837424594

# %% [markdown]
# # Conclusion

# %% [markdown]
# Clearly, Random Forest model is giving better accuracy as the mean absolute error is the least among all the other regressor models i.e. 0.13 approx. To get much better results ensemble learning techniques like Bagging and Boosting can also be used.
